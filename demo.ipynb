# %%
# %pip list
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.0.0
# aiohttp                               3.8.1
# aiosignal                             1.2.0
# ansiwrap                              0.8.4
# anyio                                 3.5.0
# appdirs                               1.4.4
# argon2-cffi                           21.3.0
# argon2-cffi-bindings                  21.2.0
# arrow                                 1.2.2
# asn1crypto                            1.5.1
# astunparse                            1.6.3
# async-timeout                         4.0.2
# asynctest                             0.13.0
# attrs                                 21.4.0
# Babel                                 2.9.1
# backcall                              0.2.0
# backports.functools-lru-cache         1.6.4
# beatrix-jupyterlab                    3.1.7
# beautifulsoup4                        4.10.0
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('owid-covid-data.csv')

# %%
df.head()
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  24-02-20          5.0        5.0
# 1      AFG      Asia  Afghanistan  25-02-20          5.0        0.0
# 2      AFG      Asia  Afghanistan  26-02-20          5.0        0.0
# 3      AFG      Asia  Afghanistan  27-02-20          5.0        0.0
# 4      AFG      Asia  Afghanistan  28-02-20          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.703610e+05  1.701940e+05        1.681970e+05  1.522700e+05
# mean   2.795644e+06  1.233400e+04        1.237313e+04  6.024709e+04
# std    1.729906e+07  8.851960e+04        8.701505e+04  3.151971e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    2.245000e+03  1.000000e+00        7.000000e+00  8.500000e+01
# 50%    2.966100e+04  7.900000e+01        1.081430e+02  8.270000e+02
# 75%    3.260600e+05  1.076000e+03        1.177143e+03  7.729750e+03
# max    4.936776e+08  4.089033e+06        3.436984e+06  6.158913e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  152284.000000        150116.000000            169572.000000
# mean      167.798731           169.617565             33531.113271
# std       819.942712           805.441903             61211.855506
# min         0.000000             0.000000                 0.001000
# ...
